# %% [markdown]
# ###Link a LinkedIn
#
# https://www.linkedin.com/in/julian-esteban-santos-martínez-4a185120a
#
# ###Certificado Data Visualization with Python
#
# ![imagen_2021-04-02_200431.png](data:image/png;base64,...)
#
#
# ###Certificado Data Visualization with Python
#
# ![image.png](data:image/png;base64,...)
#
# ### Certficado Python for Data Science
#
# ![image.png](data:image/png;base64,...)
