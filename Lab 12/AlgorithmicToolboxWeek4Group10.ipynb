# %% [markdown]
# # Laboratorio 12
# ## Grupo 10 - integrantes:
# *   Julian Esteban Santos Martinez
# *   Santiago Vargas Avendaño

# %% [markdown]
# ### 1. Binary Search

# %%
# %%writefile binarySearch.cpp
# #include <iostream>
# using namespace std;
#
# int binary_search(int a[],int low, int high, int b) {
#     if(high<low){
#         return -1;
#     }
#     int mid = low + (high-low)/2;
#     if(b==a[mid]){
#         return mid;
#     }else if(b<a[mid]){
#         return binary_search(a,low,mid-1,b);
#     }else{
#         return binary_search(a,mid+1,high,b);
#     }
# }
#
# int main() {
#     int n, k, b;
#     cin >> n;
#     int  a[n];
#     for(int i=0;i<n;i++){
#         cin >> a[i];
#     }
#     cin >> k;
#     for(int i=0;i<k;i++){
#         cin >> b;
#         cout << binary_search(a,0,n-1,b) << " ";
#     }
#     return 0;
# }
# Out:
# Writing binarySearch.cpp

# %%
# !g++ binarySearch.cpp -o binarySearch
# !./binarySearch
# Out:
# 5 1 5 8 12 13 5 8 1 23 1 11
# 2 0 -1 0 -1

# %% [markdown]
# ### 2. Majority Element

# %%
# %%writefile MajorityElement.cpp
# #include <stdio.h>
# #include <stdlib.h>
# #include <iostream>
# using namespace std;
#
# int compare (const void * a, const void * b){
#   return ( *(long long*)a - *(long long*)b );
# }
#
# int main (){
#     long long n;
#     cin >> n;
#     long long  a[n];
#     for(int i=0;i<n;i++){
#         cin >> a[i];
#     }
#     qsort (a, n, sizeof(long long), compare);
#     int m = n/2;
#     bool bandera = false;
#     for(int i=0;i<n-m;i++){
#         if(a[i]==a[m+i]){
#             cout << 1 << endl;
#             bandera = true;
#             break;
#         }
#     }
#     if(!bandera) cout << 0 << endl;
#     return 0;
# }
# Out:
# Writing MajorityElement.cpp

# %%
# !g++ MajorityElement.cpp -o MajorityElement
# !./MajorityElement
# Out:
# 1
# 2
# 1

# %% [markdown]
# ### 3. Improving Quick Sort

# %%
# %%writefile ImprovingQuickSort.cpp
# #include <iostream>
# #include <stdio.h>
# #include <stdlib.h>
# #include <iostream>
# using namespace std;
#
# int compare (const void * a, const void * b){
#   return ( *(long long*)a - *(long long*)b );
# }
#
# int main (){
#     long long n;
#     cin >> n;
#     long long  a[n];
#     for(int i=0;i<n;i++){
#         cin >> a[i];
#     }
#     qsort (a, n, sizeof(long long), compare);
#     for(int i=0;i<n;i++){
#         cout << a[i] << " ";
#     }
#     return 0;
# }
# Out:
# Writing ImprovingQuickSort.cpp

# %%
# !g++ ImprovingQuickSort.cpp -o ImprovingQuickSort
# !./ImprovingQuickSort
# Out:
# 5 2 3 9 2 2
# 2 2 2 3 9

# %% [markdown]
# Pantallazo Santiago

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pantallazo Julian

# %% [markdown]
# ![image.png](data:image/png;base64,...)
