# %% [markdown]
# # Laboratorio 11
# ## Grupo 10 - integrantes:
# *   Julian Esteban Santos Martinez
# *   Santiago Vargas Avendaño

# %% [markdown]
# ### 1. Money Change

# %%
# %%writefile MoneyChange.cpp
# #include <iostream>
# using namespace std;
#
# int number_coins(int n) {
#     return (n/10) + ((n%10)/5) + (((n%10)%5));
# }
#
# int main() {
#     int n;
#     cin >> n;
#     cout << number_coins(n) << "\n";
#     return 0;
# }
# Out:
# Writing MoneyChange.cpp

# %%
# !g++ MoneyChange.cpp -o MoneyChange
# !./MoneyChange
# Out:
# 28
# 6

# %% [markdown]
# ### 3. Car Fueling

# %%
# %%writefile CarFueling.cpp
# #include <iostream>
# using namespace std;
#
# int number_refills(int n, int m, int d, int stops[]) {
#     int refill = 0, current_refill = 0, last_refill;
#     while(current_refill<=n){
#         last_refill = current_refill;
#         while(current_refill<=n && stops[current_refill+1]-stops[last_refill]<=m){
#             current_refill++;
#         }
#         if(current_refill==last_refill) return -1;
#         if(current_refill<=n) refill++;
#     }
#     return refill;
# }
#
# int main() {
#     int d,m,n;
#     cin >> d;
#     cin >> m;
#     cin >> n;
#     int stops[n+2];
#     stops[0] = 0;
#     for(int i=1;i<=n;i++){
#         cin >> stops[i];
#     }
#     stops[n+1] = d;
#     cout << number_refills(n,m,d,stops) << "\n";
#     return 0;
# }
# Out:
# Writing CarFueling.cpp

# %%
# !g++ CarFueling.cpp -o CarFueling
# !./CarFueling
# Out:
# 950 400 4 200 375 550 750
# 2

# %% [markdown]
# ### 6 Maximum Number of Prizes

# %%
# %%writefile MaximumNumberPrizes.cpp
# #include <iostream>
# using namespace std;
#
# int portions(int k) {
#     int i = 1, portions = 0;
#     while(k>0){
#         if(k-i>i){
#             portions++;
#             k = k - i;
#             i++;
#         }else{
#             k = 0;
#             portions++;
#         }
#     }
#     return portions;
# }
#
# int main() {
#     int k, porc = 0;
#     cin >> k;
#     porc = portions(k);
#     cout << porc << "\n";
#     int i = 1, j = 0;
#     while(j<porc){
#         if(k-i>i){
#             cout << i << " ";
#             k = k - i;
#             i++;
#         }else{
#             cout << k << " ";
#         }
#         j++;
#     }
#     return 0;
# }
# Out:
# Writing MaximumNumberPrizes.cpp

# %%
# !g++ MaximumNumberPrizes.cpp -o MaximumNumberPrizes
# !./MaximumNumberPrizes
# Out:
# 8
# 3
# 1 2 5

# %% [markdown]
# Pantallazo Santiago

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pantallazo Julian

# %% [markdown]
# ![image.png](data:image/png;base64,...)
